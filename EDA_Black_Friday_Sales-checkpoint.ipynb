# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('BlackFriday.csv')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# ### Deleting the columns having null values

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# ## Analyzing Columns

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df['Age'].nunique()
# Out:
# 7

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['City_Category'].nunique()
# Out:
# 3

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].nunique()
# Out:
# 5

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Product_Category_1'].nunique()
# Out:
# 18

# %% [markdown]
# ### Total and Average amount spent by Users

# %%
print(df['Purchase'].sum())
print(df['Purchase'].mean())
# Out:
# 5017668378
# 9333.859852635065

# %% [markdown]
# ### Gender Ratio

# %%
(len(df[df['Gender']=='M'])/len(df['Gender']))*100
# Out:
# 75.40873214441838

# %%
(len(df[df['Gender']=='F'])/len(df['Gender']))*100
# Out:
# 24.59126785558162

# %%
df.groupby('Gender').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# #### most of people are males(75%) and females(25%)

# %% [markdown]
# ### How much amount spent with respect to Gender

# %% [markdown]
# ### Analyzing Age and Marital Status

# %% [markdown]
# #### Total number of purchases based on age group

# %%
df.groupby('Age').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# #### #18-45 age people are more tends to buy products in black friday sales

# %% [markdown]
# ### How many unique products are purchased by each category of Age people

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
data=pd.DataFrame(lst,columns=['Age','Unique_Products'])

# %%
data
# Out:
#      Age  Unique_Products
# 0   0-17             2300
# 1    55+             2573
# 2  26-35             3419
# 3  46-50             3099
# 4  51-55             2877
# 5  36-45             3318
# 6  18-25             3213

# %%
data.plot.bar(x='Age')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# #### #18-25,26-35,36-45 these age groups have more unique products

# %% [markdown]
# ### Total and Average amount spent with respect to age groups

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (12, 6), title = 'Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %% [markdown]
# #### #age group of 26-35 people puchased more products

# %%
df.groupby('Age')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ### How many are married and unmarried

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# #### #40% people are married and 60% are unmarried

# %% [markdown]
# ### Multi column Analysis

# %%
sns.countplot(data=df,x='Age',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# #### #males are buying more products with respect to each age  group

# %%
sns.countplot(data=df,x='Marital_Status',hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(data=df,x='City_Category')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# #### #most of the users are from City B

# %%
sns.countplot(data=df,x='Age',hue='City_Category')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x='Marital_Status',hue='City_Category')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# ### Total and Average amount spend with respect to City_Category

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### # City A people are buying costly items & City B people are buying more products but spending less amount  because City A people are just 25% but spending 32% on an average

# %% [markdown]
# ### Stay in City Analysis

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# #### # most of purchasers are staying in a city just 1 year

# %%
sns.countplot(data=df,x='Gender',hue='Stay_In_Current_City_Years')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Marital_Status',hue='Stay_In_Current_City_Years')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# #### # We can target Males who are unmarried because more purchasers are males and unmarried

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### # Avarage amount spent by people staying in 0,1,2,3,4+ are almost equal        but people staying 0,2,3,4+ years are buying costly products

# %% [markdown]
# ### Occupation and Product_Category Analysis

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# #### # people in 4,0,7,1,17,20 Occupations are tends to buy more products

# %%
df.groupby('Occupation')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# #### # people from 0,4 Occupations are buying more products but spending less amount  & remaining all Occupation people are buying costly products

# %%
sns.countplot(data=df,x='Occupation',hue='Marital_Status')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df,x='Occupation',hue='Gender')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# #### # Occupation 9 has more female purchasers

# %% [markdown]
# ### Unique products purchased with respect to occupation

# %%
df.groupby('Occupation')['Product_ID'].nunique().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Product_ID'].nunique()
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %% [markdown]
# ### Product Category 1 Analysis

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### # 80% sales are from product categories 5,1,8

# %%
df.groupby('Product_Category_1')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### # product category 4 have less sales but they are most expensive  & product category 5 have more sales but they are little bit less expensive

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ### Combining Gender and Marital status

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i]+'_'+str(df['Marital_Status'][i]))
df['MaritalGender']=l

# %%
sns.countplot(x=df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %% [markdown]
# ### # Male-Unmarried are top customers in black friday sales

# %%
sns.countplot(data=df,x='Age',hue='MaritalGender')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x='Product_Category_1',hue='MaritalGender')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(data=df,x='City_Category',hue='MaritalGender')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df,x='Stay_In_Current_City_Years',hue='MaritalGender')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>
